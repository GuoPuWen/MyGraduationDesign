# %%
import numpy as np
import cv2
from PIL import Image
from matplotlib import pyplot as plt

# %%
img = cv2.imread('./test2.jpg')
print(img)
img.shape
# Out:
# [[[213 212 198]
#   [213 212 198]
#   [213 212 198]
#   ...
#   [153 153 135]
#   [194 194 176]
#   [194 194 176]]
#
#  [[213 212 198]
#   [213 212 198]
#   [213 212 198]
#   ...
#   [159 159 141]
#   [173 173 155]
#   [186 186 168]]
#
#  [[213 212 198]
#   [213 212 198]
#   [213 212 198]
#   ...
#   [163 163 145]
#   [164 164 146]
#   [199 199 181]]
#
#  ...
#
#  [[169 181 181]
#   [169 181 181]
#   [169 181 181]
#   ...
#   [209 215 210]
#   [193 200 197]
#   [220 226 225]]
#
#  [[169 181 181]
#   [169 181 181]
#   [169 181 181]
#   ...
#   [207 213 208]
#   [176 183 180]
#   [194 202 201]]
#
#  [[169 181 181]
#   [169 181 181]
#   [169 181 181]
#   ...
#   [184 190 185]
#   [136 143 140]
#   [149 157 156]]]
# (675, 1200, 3)

# %%
gary_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
print(gary_img)
plt.imshow(gary_img)
# Out:
# [[208 208 208 ... 148 189 189]
#  [208 208 208 ... 154 168 181]
#  [208 208 208 ... 158 159 194]
#  ...
#  [180 180 180 ... 213 198 225]
#  [180 180 180 ... 211 181 201]
#  [180 180 180 ... 188 141 156]]
